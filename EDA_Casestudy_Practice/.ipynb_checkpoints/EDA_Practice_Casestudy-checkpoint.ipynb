# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import Series,DataFrame
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df=pd.read_csv("retail_data.csv",encoding='cp1252')

# %%
df.head()
# Out:
#       Month Enquiry Date      Enquiry Id Allocation Status Status      State  \
# 0  April'16    02-Apr-16   EC02041646800            Dealer    Won  TAMILNADU
# 1  April'16    08-Apr-16   EC08041647157            Dealer   Lost  TAMILNADU
# 2  April'16    08-Apr-16   EC08041647130            Dealer   Lost  TAMILNADU
# 3  April'16    09-Apr-16   EC09041647202            Direct   Lost  TAMILNADU
# 4  April'16    11-Apr-16   EC11041647360            Direct    Won  TAMILNADU
#
#           City  Pincode   Type of Project No of Windows          ...           \
# 0      CHENNAI   600008        Renovation       6 to 10          ...
# 1      CHENNAI   600042  New Construction       6 to 10          ...
# 2      CHENNAI   600015  New Construction        1 to 5          ...
# 3  KANCHIPURAM   600075  New Construction      21 to 40          ...
# 4      CHENNAI   600041        Renovation       6 to 10          ...
#
#   Second Action-Call Status.1         Remarks Price Per Sft  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 40 columns):
# Month                                        229 non-null object
# Enquiry Date                                 229 non-null object
# Enquiry Id                                   229 non-null object
# Allocation Status                            229 non-null object
# Status                                       229 non-null object
# State                                        229 non-null object
# City                                         229 non-null object
# Pincode                                      229 non-null int64
# Type of Project                              229 non-null object
# No of Windows                                229 non-null object
# Source                                       229 non-null object
# Zone                                         229 non-null object
# Dealer Name                                  229 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# Month                                          0
# Enquiry Date                                   0
# Enquiry Id                                     0
# Allocation Status                              0
# Status                                         0
# State                                          0
# City                                           0
# Pincode                                        0
# Type of Project                                0
# No of Windows                                  0
# Source                                         0
# Zone                                           0
# Dealer Name                                    0
# First Action-Call made                         0
# Date DD/MM/YY                                  0
# First Action-Call Status                       0
# Date of Appointment (DD/MM/YY)                37
# Second Action-Customer Meeting                37
# Date DD/MM/YY.1                               37
# ...

# %%
df.dtypes
# Out:
# Month                                         object
# Enquiry Date                                  object
# Enquiry Id                                    object
# Allocation Status                             object
# Status                                        object
# State                                         object
# City                                          object
# Pincode                                        int64
# Type of Project                               object
# No of Windows                                 object
# Source                                        object
# Zone                                          object
# Dealer Name                                   object
# First Action-Call made                        object
# Date DD/MM/YY                                 object
# First Action-Call Status                      object
# Date of Appointment (DD/MM/YY)                object
# Second Action-Customer Meeting                object
# ...

# %%
df['Allocation Status'].value_counts()
# Out:
# Dealer    165
# Direct     64
# Name: Allocation Status, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Lost    176
# Won      53
# Name: Status, dtype: int64

# %%
dealer_name = df[df['Allocation Status']=='Dealer']

# %%
dealer_name = dealer_name[dealer_name['Dealer Name']!='Direct']

# %%
dealer_name['Allocation Status'].value_counts()
# Out:
# Dealer    165
# Name: Allocation Status, dtype: int64

# %% [markdown]
# ### Visualisation

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x="Dealer Name", data=dealer_name,order=dealer_name['Dealer Name'].value_counts().index)

# %%
pd.crosstab(dealer_name['Dealer Name'],dealer_name['Zone'])
# Out:
# Zone         Chennai  Kanchipuram
# Dealer Name
# Direct             4            0
# ITP               13            0
# OXXO              20            0
# Pearlson           8            0
# Rajtechnis        15            0
# Sunbird           32            1
# Windoors          45            0
# Winfratech        20            0
# pearlson           7            0

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(15,8))
sns.countplot(x='Dealer Name',hue='Status',data=dealer_name)

# %%
ax = sns.countplot(x="Type of Project", data=df)

# %%
df['Total Sales'] = df['Q Val. (Rs. Lac)']*df['Order QTY']

# %%
# Out:
# Total Sales  0.01    0.15    0.20    0.21    0.25    0.36    0.37    0.40    \
# Dealer Name
# Direct            0       0       0       0       1       1       0       0
# OXXO              0       0       0       0       0       0       0       1
# Pearlson          0       0       0       0       0       0       0       0
# Rajtechnis        0       0       0       0       0       0       0       0
# Sunbird           0       0       1       0       0       0       1       0
# Windoors          1       0       0       0       0       0       0       0
# Winfratech        0       0       0       1       0       0       0       0
# pearlson          0       1       0       0       0       0       0       0
#
# Total Sales  0.46    0.52     ...    27.50   34.68   55.02   72.00   105.84  \
# Dealer Name                   ...
# Direct            1       1   ...         0       0       1       1       1
# OXXO              0       0   ...         0       0       0       0       0
# ...
